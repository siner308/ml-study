# %%
import pandas as pd

# %%
data = pd.read_csv('stat_list_with_result.csv')

# %%
data.count()
# Out:
# Unnamed: 0                         4476
# away-accurate_back_zone_pass-1     4466
# away-accurate_back_zone_pass-2     4456
# away-accurate_back_zone_pass-3     4447
# away-accurate_chipped_pass-1       4455
# away-accurate_chipped_pass-2       4437
# away-accurate_chipped_pass-3       4419
# away-accurate_corners_intobox-1    3395
# away-accurate_corners_intobox-2    3250
# away-accurate_corners_intobox-3    3290
# away-accurate_cross-1              4398
# away-accurate_cross-2              4362
# away-accurate_cross-3              4359
# away-accurate_cross_nocorner-1     4246
# away-accurate_cross_nocorner-2     4147
# away-accurate_cross_nocorner-3     4179
# away-accurate_freekick_cross-1     1254
# away-accurate_freekick_cross-2     1167
# away-accurate_freekick_cross-3     1165
# away-accurate_fwd_zone_pass-1      4466
# away-accurate_fwd_zone_pass-2      4456
# away-accurate_fwd_zone_pass-3      4447
# away-accurate_goal_kicks-1         4361
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  away-accurate_back_zone_pass-1  \
# count  4476.000000                     4466.000000
# mean   2237.500000                      148.499328
# std    1292.254232                       58.418885
# min       0.000000                       30.000000
# 25%    1118.750000                      104.000000
# 50%    2237.500000                      143.000000
# 75%    3356.250000                      184.000000
# max    4475.000000                      401.000000
#
#        away-accurate_back_zone_pass-2  away-accurate_back_zone_pass-3  \
# count                     4456.000000                     4447.000000
# mean                       147.570467                      147.721610
# std                         59.139804                       58.110082
# min                         32.000000                       30.000000
# 25%                        103.000000                      104.000000
# 50%                        141.000000                      141.000000
# ...

# %%
import numpy as np
data = data.replace('np.nan', 0)

# %%
data.info()
# Out:
#         Unnamed: 0  away-accurate_back_zone_pass-1  \
# count  4476.000000                     4466.000000
# mean   2237.500000                      148.499328
# std    1292.254232                       58.418885
# min       0.000000                       30.000000
# 25%    1118.750000                      104.000000
# 50%    2237.500000                      143.000000
# 75%    3356.250000                      184.000000
# max    4475.000000                      401.000000
#
#        away-accurate_back_zone_pass-2  away-accurate_back_zone_pass-3  \
# count                     4456.000000                     4447.000000
# mean                       147.570467                      147.721610
# std                         59.139804                       58.110082
# min                         32.000000                       30.000000
# 25%                        103.000000                      104.000000
# 50%                        141.000000                      141.000000
# ...

# %%
for row in data:
    data[row].fillna(0, inplace=True)
